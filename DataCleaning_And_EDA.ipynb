# %% [markdown]
# <a href="https://colab.research.google.com/github/maryam01k/PAI_PROJECT/blob/main/DataCleaning_And_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
# uploaded = files.upload()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pesticides_df = pd.read_excel('pesticidesData.xls', usecols=range(16))
df = pesticides_df.copy()
df.head()
# Out:
#    S.No.  R. No.             Date           Job No.                 Firm Name  \
# 0    1.0     2.0  02-January,2017      C/PK/QC16015            Exin Chemicals
# 1    2.0     2.0  02-January,2017  C/S/PK/170059/16             New Agri Care
# 2    3.0     1.0  02-January,2017        CU16119148  Tara Imperial Industries
# 3    4.0     4.0  02-January,2017        CU16119110  Tara Imperial Industries
# 4    5.0     4.0  03-January,2017      PK-130617/16       Sun Crop Pesticides
#
#    Brand Name            Comman Name                 Formulation  \
# 0    Xiaowang  Mesotrione + Atrazine  55% soluble concentration
# 1        Deft     Metsulfuron Methyl       10% waightable powder
# 2         NaN             Glyphosate         41% soluble liquid
# 3         NaN   Metalaxyl + Mancozeb      72% waightable powder
# 4  Truce Xtra  Mesotrione + Atrazine  88.8% weightable granulers
#
#    Quantity (lit/kg)  C & F\nValue  Ex.Rate  (US$)  Total Value (Rs.) Origin  \
# 0            16000.0          3.30           106.0          5596800.0  China
# 1             2000.0          3.37           106.0           714440.0  China
# 2            32000.0          1.78           106.0          6037760.0  China
# 3            15000.0          3.60           106.0          5724000.0  China
# 4             1000.0          8.50           106.0           901000.0  China
#
#   Reg. No.   PSI   Category
# 0   R-1912  NMCI      Herb.
# 1    R-908  NMCI      Herb.
# 2   R-6945    CU      Herb.
# 3   R-4982    CU  Fungicide
# 4   R-1983  NMCI      Herb.

# %%
df.columns = df.columns.str.strip().str.replace('\n', '').str.replace('  ', ' ')
print(df.columns.tolist())  # verify cleaned names
# Out:
# ['S.No.', 'R. No.', 'Date', 'Job No.', 'Firm Name', 'Brand Name', 'Comman Name', 'Formulation', 'Quantity (lit/kg)', 'C & FValue', 'Ex.Rate (US$)', 'Total Value (Rs.)', 'Origin', 'Reg. No.', 'PSI', 'Category']

# %%
df['Total Value (Rs.)'] = df['Quantity (lit/kg)']*df['C & FValue']*df['Ex.Rate (US$)']

# %%
df.drop(columns=['S.No.','R. No.','Ex.Rate (US$)'],inplace=True)
df['Brand Name'].fillna("Form-16",inplace=True)
# Out:
# /tmp/ipython-input-1601225596.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Brand Name'].fillna("Form-16",inplace=True)

# %%
from dateutil import parser

def parse_messy_date(date_str):
    try:
        parsed_date = parser.parse(date_str, dayfirst=True, fuzzy=True)
        return parsed_date.strftime('%Y-%m-%d')
    except (ValueError, TypeError):
        return np.nan
df['Date'] = df['Date'].apply(parse_messy_date)

# %%
pd.set_option('display.max_rows', None)
df['Formulation'].value_counts()
# Out:
# Formulation
# 80% weightable granulers           133
# 25% waightable powder              129
# 15% waightable powder               67
# 72% waightable powder               64
# 70% waightable powder               52
# 75% soluble powder                  49
# 20% soluble liquid                  44
# 55% soluble concentration           41
# 55% soluble concentration           40
# 40% emulsifier concentration        39
# 50% emulsifier concentration        32
# 480 G/L soluble liquid              31
# 75% weightable granulers            26
# 50% waightable powder               21
# 80% WDG                             21
# 0.5% AS                             19
# 80% waightable powder               18
# 72% waightable powder               16
# 480% G/L soluble liquid             14
# 10.8% emulsifier concentration      14
# 70% waightable powder               13
# 80% waightable powder               12
# 80% soluble powder                  12
# 1.9% emulsifier concentration       12
# 60% emulsifier concentration        12
# 200 soluble liquid                  11
# 20% soluble powder                  11
# 50% waightable powder               10
# 1.8% emulsifier concentration       10
# 25% soluble liquid                  10
# 480 g/l soluble liquid              10
# 30% waightable powder               10
# 70% weightable granulers             9
# 480 GL                               9
# 50% soluble concentration            9
# 50% weightable granulers             8
# 25%waightable powder                 8
# 5% emulsifier concentration          8
# 56% Tab                              7
# 48% soluble concentration            7
# 10% emulsifier concentration         7
# 16% KPP                              7
# 38% soluble concentration            7
# 56% Tablets                          7
# 60% weightable granulers             6
# 960% emulsifier concentration        6
# 56% (ALP)                            6
# 47% waightable powder                6
# 20% soluble concentration            6
# 15% waightable powder                6
# 372.5 flowable suspension            5
# 56%  Tablets                         5
# 5% WDG                               5
# 80% DF                               5
# 20% waightable powder                5
# 2.5% emulsifier concentration        5
# 3% soluble concentration             5
# 5% soluble concentration             5
# 25 weightable granulers              5
# 75% waightable powder                5
# 480% G/L                             5
# 120 soluble concentration            5
# 50% soluble concentration            4
# 325 soluble concentration            4
# 26% WDG                              4
# 60% WDG                              4
# 12% soluble concentration            4
# 10% waightable powder                4
# 38% soluble concentration            4
# 20% soluble liquid                   4
# 24% waightable powder                4
# 75% WDG                              4
# 240 soluble concentration            4
# 70% WS                               4
# 20% emulsifier concentration         4
# 50 emulsifier concentration          4
# 25% waightable powder                3
# 336 (g/l)                            3
# 24% emulsifier concentration         3
# 33% emulsifier concentration         3
# 40% soluble powder                   3
# 36% soluble concentration            3
# 40% soluble concentration            3
# 41% soluble liquid                   3
# 30% soluble concentration            3
# 051 soluble concentration            3
# 71% SG                               3
# 050 emulsifier concentration         3
# 480% GL                              3
# 48% emulsifier concentration         3
# 18% CF                               3
# 480 g/l                              3
# 40% waightable powder                3
# 3.6% weightable granulers            3
# 019 emulsifier concentration         3
# 32.5% soluble concentration          3
# 26% OD                               3
# 36% soluble concentration            3
# 47% waightable powder                2
# 25% weightable granulers             2
# 98% + 2% Chloropicrin                2
# 0.75                                 2
# 75% waightable powder                2
# 70% waightable powder                2
# 15% EO                               2
# 29.5% waightable powder              2
# 336 (g/l) soluble concentration      2
# 69% waightable powder                2
# 4 emulsifier concentration           2
# 98%+2                                2
# 60%weightable granulers              2
# 28% waightable powder                2
# 48% soluble concentration            2
# 30% WDG                              2
# 440 soluble concentration            2
# 525 SE                               2
# 480 G/L                              2
# 20% SG                               2
# 25% emulsifier concentration         2
# 540 (g/l) soluble liquid             2
# 55%soluble concentration             2
# 80% weightable granulers             2
# 24% OD                               2
# 3% soluble concentration             2
# 500 emulsifier concentration         2
# 720 soluble concentration            2
# 40% weightable granulers             2
# 36% emulsifier concentration         2
# 35% emulsifier concentration         2
# 36% soluble liquid                   2
# 372.5 flowable suspension            2
# 480 soluble concentration            2
# 36% waightable powder                2
# 98% + 2%                             2
# 300 soluble concentration            2
# 240 soluble concentration            2
# 40% emulsifier concentration         2
# 80%weightable granulers              2
# 88.8% weightable granulers           2
# 25% emulsifier concentration         2
# 5% EW                                2
# 30% soluble concentration            2
# 33%emulsifier concentration          2
# 455 (g/l) CS                         2
# 0.5% AS                              2
# 51.8% soluble powder                 2
# 10% soluble concentration            2
# 32.5% soluble concentration          2
# 31%emulsifier concentration          2
# 30% emulsifier concentration         2
# 75%weightable granulers              2
# 66.8% waightable powder              2
# 68% weightable granulers             2
# 25% soluble powder                   2
# 70%  waightable powder               1
# 80% emulsifier concentration         1
# 25% OD                               1
# 80% WDG                              1
# 12% emulsifier concentration         1
# 85% soluble powder                   1
# 24% emulsifier concentration         1
# 580 waightable powder                1
# 12.5% emulsifier concentration       1
# 36% waightable powder                1
# 48% soluble liquid                   1
# 52.4% weightable granulers           1
# 56% ALP Tablets                      1
# 051 soluble concentration            1
# 4%emulsifier concentration           1
# 2.5% OD                              1
# 1.8% ME                              1
# 10% soluble liquid                   1
# 56% emulsifier concentration         1
# 580 waightable powder                1
# 100 flowable suspension              1
# 80% WDG (20% + 60%)                  1
# 440 emulsifier concentration         1
# 960 emulsifier concentration         1
# 1.9% emulsifier concentration        1
# 960 emulsifier concentration         1
# 30%soluble concentration             1
# 6% weightable granulers              1
# 75 EW                                1
# 16% waightable powder                1
# 50% soluble liquid                   1
# 70%weightable granulers              1
# 25% soluble concentration            1
# 500 soluble concentration            1
# 57% emulsifier concentration         1
# 125 flowable suspension              1
# 250 soluble concentration            1
# 20% ME                               1
# 480% G/L                             1
# 98                                   1
# 40% soluble concentration            1
# 68% weightable granulers             1
# 56% Plates/Strips                    1
# 80% soluble concentration            1
# 45 OD                                1
# 18.7% weightable granulers           1
# 60% waightable powder                1
# 0.02% Concentrate Bait               1
# 43.5% emulsifier concentration       1
# 8% OF                                1
# 360% emulsifier concentration        1
# 75 waightable powder                 1
# 100 emulsifier concentration         1
# 50%emulsifier concentration          1
# 77% waightable powder                1
# 0.4% G                               1
# 5.6% emulsifier concentration        1
# 98+2                                 1
# 560% soluble concentration           1
# 22% ZC                               1
# 26% soluble concentration            1
# 65% Tab                              1
# 44% emulsifier concentration         1
# 051 G/L soluble liquid               1
# 108 (g/l) soluble concentration      1
# 70 Ws                                1
# 16% Od                               1
# 22% emulsifier concentration         1
# 15% emulsifier concentration         1
# 5% Sc                                1
# 40% Wsoluble powder                  1
# 98% W/W                              1
# 2% soluble liquid                    1
# 16% OD                               1
# 480 g/l soluble concentration        1
# 56% (ALP) Tab                        1
# 360 emulsifier concentration         1
# 56% (ALP) Tablets                    1
# 70 WS                                1
# 97% DF                               1
# 440% emulsifier concentration        1
# 1.9%emulsifier concentration         1
# 98+2 %                               1
# 11.8% emulsifier concentration       1
# 80% SG                               1
# 525 (g/l) SE                         1
# 9.1% weightable granulers            1
# 50% emulsifier concentration         1
# 50% WDG                              1
# 60% weightable granulers             1
#  70% waightable powder               1
# 48% soluble liquid                   1
# 525 (g/l)                            1
# 240 soluble concentration            1
# 8%soluble concentration              1
# 31% emulsifier concentration         1
# 25% ZC                               1
# 25% Wp                               1
# 240 flowable suspension              1
# 70 waightable powder                 1
# 30% weightable granulers             1
# 56% Plates                           1
# 10%emulsifier concentration          1
# 25%weightable granulers              1
# 11% OD                               1
# 51.8%soluble powder                  1
# 120% SE                              1
# 28.6% SG                             1
# 22% soluble concentration            1
# 100 % emulsifier concentration       1
# 60 soluble concentration             1
# 960% G/L                             1
# 30% soluble liquid                   1
# 036 flowable suspension              1
# 6% ME                                1
# 28% soluble liquid                   1
# 28% soluble powder                   1
# 25%soluble concentration             1
# 78% waightable powder                1
# WS 70                                1
# 38% soluble liquid                   1
# 98 + 2                               1
# Name: count, dtype: int64

# %%
import re

# Regex to match either:
# 1. number (with optional %) at the start, then type
# 2. OR type at the start, number at the end
pattern = r"""
    ^\s*
    (?:
        (?P<Percentage1>\d+(?:\.\d+)?)       # number at start
        (?:%)?                               # optional %
        \s*(?P<Type1>.+)                     # type after number
    |
        (?P<Type2>[A-Za-z\s]+)               # type at start
        \s*(?P<Percentage2>\d+(?:\.\d+)?)    # number at end
    )
    \s*$
"""

extracted = df['Formulation'].str.extract(pattern, flags=re.VERBOSE)

df['Percentage'] = extracted['Percentage1'].combine_first(extracted['Percentage2'])
df['Type'] = extracted['Type1'].combine_first(extracted['Type2'])

df['Percentage'] = pd.to_numeric(df['Percentage'], errors='coerce')
df['Type'] = df['Type'].str.strip()

df.dropna(subset=['Percentage','Type'],inplace=True)

# %%
df.head(10)
# Out:
#          Date           Job No.                   Firm Name  Brand Name  \
# 0  2017-01-02      C/PK/QC16015              Exin Chemicals    Xiaowang
# 1  2017-01-02  C/S/PK/170059/16               New Agri Care        Deft
# 2  2017-01-02        CU16119148    Tara Imperial Industries     Form-16
# 3  2017-01-02        CU16119110    Tara Imperial Industries     Form-16
# 4  2017-01-03      PK-130617/16         Sun Crop Pesticides  Truce Xtra
# 5  2017-01-03        CU16119088          Sino Pak Chemicals     Form-16
# 6  2017-01-03      BTIN/1247/16  Four Brothers Agri Service     Form-16
# 7  2017-01-04        CU16119140        Sayban International     Form-16
# 8  2017-01-04        CU16129171                ICI Pakistan     Form-16
# 9  2017-01-04        CU16119029         Pak China Chemicals     Form-16
#
#              Comman Name                 Formulation  Quantity (lit/kg)  \
# 0  Mesotrione + Atrazine  55% soluble concentration             16000.0
# 1     Metsulfuron Methyl       10% waightable powder             2000.0
# 2             Glyphosate         41% soluble liquid             32000.0
# 3   Metalaxyl + Mancozeb      72% waightable powder             15000.0
# 4  Mesotrione + Atrazine  88.8% weightable granulers             1000.0
# 5            Trichlorfon          80% soluble powder            32000.0
# 6   Clodinafop Propargyl      15% waightable powder             10000.0
# 7            Trichlorfon          80% soluble powder            16000.0
# 8            Trichlorfon          80% soluble powder            25344.0
# 9    Aluminium Phosphide                56%  Tablets            25032.0
#
#    C & FValue  Total Value (Rs.) Origin Reg. No.     PSI   Category  \
# 0        3.30          5596800.0  China   R-1912    NMCI      Herb.
# 1        3.37           714440.0  China    R-908    NMCI      Herb.
# 2        1.78          6037760.0  China   R-6945      CU      Herb.
# 3        3.60          5724000.0  China   R-4982      CU  Fungicide
# 4        8.50           901000.0  China   R-1983    NMCI      Herb.
# 5        2.50          8480000.0  China   R-6829      CU    Insect.
# 6       10.45         11077000.0  India   R-5975  BALTIC      Herb.
# 7        1.65          2798400.0  China   R-6613      CU    Insect.
# 8        4.15         11148825.6  China   R-5818      CU    Insect.
# 9        3.85         10215559.2  China   R-3550      CU   Fumigant
#
#   Origin_Name  Percentage                   Type
# 0         NaN        55.0  soluble concentration
# 1         NaN        10.0      waightable powder
# 2         NaN        41.0         soluble liquid
# 3         NaN        72.0      waightable powder
# 4         NaN        88.8   weightable granulers
# 5         NaN        80.0         soluble powder
# 6         NaN        15.0      waightable powder
# 7         NaN        80.0         soluble powder
# 8         NaN        80.0         soluble powder
# 9         NaN        56.0                Tablets

# %%
df['Percentage'].value_counts(ascending=False).sort_index(ascending=True)
# Out:
# Percentage
# 0.02        1
# 0.40        1
# 0.50       21
# 1.80       11
# 1.90       14
# 2.00        1
# 2.50        6
# 3.00        7
# 3.60        3
# 4.00        3
# 5.00       21
# 5.60        1
# 6.00        2
# 8.00        2
# 9.10        1
# 10.00      15
# 10.80      14
# 11.00       1
# 11.80       1
# 12.00       5
# 12.50       1
# 15.00      76
# 16.00      10
# 18.00       3
# 18.70       1
# 19.00       3
# 20.00      77
# 22.00       3
# 24.00      10
# 25.00     169
# 26.00       8
# 28.00       4
# 28.60       1
# 29.50       2
# 30.00      22
# 31.00       3
# 32.50       5
# 33.00       5
# 35.00       2
# 36.00      14
# 38.00      12
# 40.00      54
# 41.00       3
# 43.50       1
# 44.00       1
# 45.00       1
# 47.00       8
# 48.00      14
# 50.00      95
# 51.00       5
# 51.80       3
# 52.40       1
# 55.00      83
# 56.00      31
# 57.00       1
# 60.00      27
# 65.00       1
# 66.80       2
# 68.00       3
# 69.00       2
# 70.00      87
# 71.00       3
# 72.00      80
# 75.00      90
# 77.00       1
# 78.00       1
# 80.00     210
# 85.00       1
# 88.80       2
# 97.00       1
# 98.00      10
# 100.00      3
# 108.00      1
# 120.00      6
# 125.00      1
# 200.00     11
# 240.00      8
# 250.00      1
# 300.00      2
# 325.00      4
# 336.00      5
# 360.00      2
# 372.50      7
# 440.00      4
# 455.00      2
# 480.00     81
# 500.00      3
# 525.00      4
# 540.00      2
# 560.00      1
# 580.00      2
# 720.00      2
# 960.00      9
# Name: count, dtype: int64

# %%
df['Type'].value_counts(ascending=False).sort_index(ascending=True)
# Out:
# Type
# % emulsifier concentration       1
# (ALP)                            6
# (ALP) Tab                        1
# (ALP) Tablets                    1
# (g/l)                            4
# (g/l) CS                         2
# (g/l) SE                         1
# (g/l) soluble concentration      3
# (g/l) soluble liquid             2
# + 2                              1
# + 2%                             2
# + 2% Chloropicrin                2
# +2                               3
# +2 %                             1
# ALP Tablets                      1
# AS                              21
# CF                               3
# Concentrate Bait                 1
# DF                               6
# EO                               2
# EW                               3
# G                                1
# G/L                              9
# G/L soluble liquid              46
# GL                              12
# KPP                              7
# ME                               3
# OD                              10
# OF                               1
# Od                               1
# Plates                           1
# Plates/Strips                    1
# SE                               3
# SG                               7
# Sc                               1
# Tab                              8
# Tablets                         12
# W/W                              1
# WDG                             42
# WDG (20% + 60%)                  1
# WS                               6
# Wp                               1
# Ws                               1
# Wsoluble powder                  1
# ZC                               2
# emulsifier concentration       214
# flowable suspension             11
# g/l                              3
# g/l soluble concentration        1
# g/l soluble liquid              10
# soluble concentration          199
# soluble liquid                  82
# soluble powder                  82
# waightable powder              483
# weightable granulers           215
# Name: count, dtype: int64

# %%
df['Type'] = (
    df['Type']
    .astype(str)
    .str.strip()
    .str.upper()
    .str.replace(r'[%()+/]', ' ', regex=True)
    .str.replace(r'[^A-Z0-9\s]', '', regex=True)
    .str.replace(r'\s+', ' ', regex=True)
    .str.strip()
)

replace_map = {
    'ALP': 'ALP TABLETS',
    'ALP TAB': 'ALP TABLETS',
    'TAB': 'ALP TABLETS',
    'TABLET': 'ALP TABLETS',
    'TABLETS': 'ALP TABLETS',
    'WP': 'WAIGHTABLE POWDER',
    'WDG 20 60': 'WDG',
    'WS': 'WATER SOLUBLE POWDER',
    'WSOLUBLE POWDER': 'WATER SOLUBLE POWDER',
    'SOLUBLE POWDER': 'WATER SOLUBLE POWDER',
    'SC': 'SOLUBLE CONCENTRATE',
    'OF': 'OIL FORMULATION',
    'OD': 'OIL DISPERSION',
    'EW': 'EMULSION, OIL IN WATER',
    'EC': 'EMULSIFIABLE CONCENTRATE',
    'EMULSIFIER CONCENTRATION': 'EMULSIFIABLE CONCENTRATE',
    'EMULSION CONCENTRATION': 'EMULSIFIABLE CONCENTRATE',
    'DF': 'DRY FLOWABLE',
    'ME': 'MICRO EMULSION',
    'G L CS': 'GRAMS PER LITRE SOLUBLE CONCENTRATE',
    'G L SOLUBLE CONCENTRATION': 'GRAMS PER LITRE SOLUBLE CONCENTRATE',
    'G L SOLUBLE LIQUID': 'GRAMS PER LITRE SOLUBLE LIQUID',
    'G L SE': 'GRAMS PER LITRE SUSPENSION EMULSION',
    'G/L': 'GRAMS PER LITRE',
    'GL': 'GRAMS PER LITRE',
    'G L': 'GRAMS PER LITRE',
    'SOLUBLE CONCENTRATION': 'SOLUBLE CONCENTRATE',
    'ZC': 'MIXED FORMULATION (ZC)',
    'AS': 'AQUEOUS SOLUTION',
    'SE': 'SUSPENSION EMULSION',
    'SG': 'SOLUBLE GRANULES',
    'KPP': 'KILOGRAMS PER PACK',
    'CF': 'CONTROL FORMULATION',
    'EO': 'EMULSION, OIL IN WATER',
    'G': 'GRAMS PER LITRE',
    'W W': 'WEIGHT BY WEIGHT',
    'W W PERCENTAGE': 'WEIGHT BY WEIGHT',
    '+2': '2% CHLOROPICRIN',
    '2': '2% CHLOROPICRIN',
    '2 PERCENT': '2% CHLOROPICRIN',
    '2 CHLOROPICRIN': '2% CHLOROPICRIN',
    'PLATES STRIPS': 'PLATES',
}

# Normalize using replacement dictionary
df['Type'] = df['Type'].replace(replace_map)
df['Type'].value_counts(ascending=False).sort_index(ascending=True)
# Out:
# Type
# 2% CHLOROPICRIN                          9
# ALP TABLETS                             29
# AQUEOUS SOLUTION                        21
# CONCENTRATE BAIT                         1
# CONTROL FORMULATION                      3
# DRY FLOWABLE                             6
# EMULSIFIABLE CONCENTRATE               215
# EMULSION, OIL IN WATER                   5
# FLOWABLE SUSPENSION                     11
# GRAMS PER LITRE                         29
# GRAMS PER LITRE SOLUBLE CONCENTRATE      6
# GRAMS PER LITRE SOLUBLE LIQUID          58
# GRAMS PER LITRE SUSPENSION EMULSION      1
# KILOGRAMS PER PACK                       7
# MICRO EMULSION                           3
# MIXED FORMULATION (ZC)                   2
# OIL DISPERSION                          11
# OIL FORMULATION                          1
# PLATES                                   2
# SOLUBLE CONCENTRATE                    200
# SOLUBLE GRANULES                         7
# SOLUBLE LIQUID                          82
# SUSPENSION EMULSION                      3
# WAIGHTABLE POWDER                      484
# WATER SOLUBLE POWDER                    90
# WDG                                     43
# WEIGHT BY WEIGHT                         1
# WEIGHTABLE GRANULERS                   215
# Name: count, dtype: int64

# %%
df = df.drop('Formulation', axis=1)

# %%
df = df.rename(columns={
    'Common Name': 'Composition'
})

# %%
df['Category'].value_counts()
# Out:
# Category
# Herb.          500
# Insect.        429
# Fung.          274
# Fungicide      202
# Insect          79
# Fumigant        31
# Biological      21
# Fum.             3
# Insecticide      2
# Acaracide        1
# Acracide         1
# Fumigation       1
# Acari            1
# Name: count, dtype: int64

# %%
category_mapping = {
    'Herb.': 'Herbicide',
    'Fung.': 'Fungicide',
    'Insect.': 'Insecticide',
    'Insect': 'Insecticide',
    'Fumigation': 'Fumigant',
    'Fum.': 'Fumigant',
    'Acari': 'Acaricide',
    'Acaracide': 'Acaricide',
    'Acracide': 'Acaricide',
}

# %%
df['Category'] = df['Category'].replace(category_mapping)

# %%
df['Category'].value_counts()
# Out:
# Category
# Insecticide    510
# Herbicide      500
# Fungicide      476
# Fumigant        35
# Biological      21
# Acaricide        3
# Name: count, dtype: int64

# %%
import re

def normalize_firm_name(name):
    if not isinstance(name, str):
        return ""

    name = name.upper()
    name = re.sub(r'[^\w\s]', '', name)
    name = re.sub(r'\s+', ' ', name).strip()

    replacements = {
        'PRIVATE LIMITED': '', 'PVT LTD': '', 'LTD': '', 'LIMITED': '', 'PVT': '',
        'ENTERPRISES': 'ENTERPRISE',
        'ENTREPRENUER': 'ENTREPRENEUR',
        'ENTERPRENEUR': 'ENTREPRENEUR',
        'ENTREPRENEUR': 'ENTERPRISE',
        'CHEMCIALS': 'CHEMICALS',
        'CHEMICALES': 'CHEMICALS',
        'CHEMICALS': 'CHEMICAL',
        'PESTICIDES': 'PESTICIDE',
        'PESTISIDE': 'PESTICIDE',
        'SCIENCES': 'SCIENCE',
        'LIFESCIENCE': 'LIFE SCIENCE',
        'AGROSCIENCE': 'AGRO SCIENCE',
        'AGROSCIENCES': 'AGRO SCIENCE',
        'SERVICES': 'SERVICE',
        'DISTRIBUTERS': 'DISTRIBUTORS',
        'DISTRIBUTION': 'DISTRIBUTORS',
        'CENTER': 'CENTRE',
        'CORP': 'CORPORATION',
        'CORPORATIONORATION': 'CORPORATION',
        'ALNOOR': 'AL NOOR',
        'AGROTREE': 'AGRO TREE',
        'AGROCHINA': 'AGRO CHINA',
        'RICECO': 'RICE CO',
        'WELCOM AGRO': 'WELCOME AGRO',
        'WELCOME AGRO CHEMICAL': 'WELCOME AGRO',
        'WELCOME CHEMICAL': 'WELCOME AGRO',
        'WELCON AGRO CHEMICAL': 'WELCOME AGRO',
        'WELCON CHEMICAL': 'WELCOME AGRO',
        'WELCONE CHEMICAL': 'WELCOME AGRO',
        ' KARACHI': '',
        'PAKISTAN': '',
        'INDUSTRIES': '',
        'STEDECT': 'STEDEC',
        'CORPORATION': '',
        'FOR': '4',
        'R B': 'RB',
        'SERVICE': '',
        'SCIENCE': '',
        'BIOLOGIC AG': 'AGRI',
        'FOURBROTHERS': 'FOURBROTHER',
        'FMC': 'FM',
        'S ESSA': 'SESSA',
    }

    for old, new in replacements.items():
        name = name.replace(old, new)

    name = re.sub(r'\s+', ' ', name).strip()

    return name

df['Firm Name'] = df['Firm Name'].apply(normalize_firm_name)

# %%
manual_firm_map = {
    'ABDULLAH HASEEB': 'ABDULLAH HASEEB AGRO CHEMICAL',
    'AGGRIO':'AGGRIO CHEMICAL',
    'AGRI 4CE': 'AGRI 4CE CHEMICAL',
    'AGRO': 'AGRO TREE LIFE',
    'AGROW': 'AGROW MARK',
    'AJMA CHEM': 'AJMA CHEMICAL',
    'AGRO CHEMICAL': 'AL NOOR AGRO CHEMICAL',
    'ARYSTA LIFE SCIENE': 'ARYSTA LIFE',
    'AURIGA CHEMICAL ENTERPRISE': 'AURIGA CHEMICAL',
    'CAPRICORN': 'CAPRICORN ASSOCIATIONS',
    'COMMANDER AGRO CHEMICAL': 'COMMANDER AGRO',
    'DU PONT OPERATIONS': 'DUPONT',
    'DUPENT OPERATION': 'DUPONT',
    'FOURBROTHER AGRI': 'FOURBROTHER BIOLOGIC',
    'FOURBROTHERBIOLOGIC': 'FOURBROTHER BIOLOGIC',
    'HELB AGRO CHEMICAL': 'HELB AGRO',
    'HELB PESTICIDE CHEMICAL': 'HELB PESTICIDE',
    'HEXTAR CHEMICAL ENTERPRISE': 'HEXTAR CHEMICAL',
    'NAFEES ENTERPRENUER': 'NAFEES ENTERPRISE',
    'PRIME BIOLOGICAL': 'PRIME BIOLOGICAL ENTERPRISE',
}

manual_firm_map_normalized = {normalize_firm_name(k): v for k, v in manual_firm_map.items()}

df['Firm Name'] = df['Firm Name'].replace(manual_firm_map_normalized)


df['Brand Name'].value_counts(ascending=False).sort_index(ascending=True)
# Out:
# Brand Name
# Acelam                         4
# Acord                          1
# Pucheng Star                   6
# Puffer                        10
# Puma Super                     1
# Pyramid Plus                   2
# Radiant                        5
# Rally                          2
# Recado                         4
# Recado Xtra                    6
# Regent                         4
# Rescue                         1
# Revus                          1
# Ridomil Gold MZ                2
# Ridomil Gold Mz                1
# Rifit                          2
# Romeo                          3
# Romer                          1
# Roundup Power Max              2
# Rovral                         1
# Runner                         1
# Saaf                           2
# Saprofon                       2
# Scotts                         1
# Sega                           1
# Sega Pest Clear                7
# Segawin                        4
# Sencor                         1
# Sevin                          1
# Shincar                        2
# Shogun                         1
# Shuang Cao Ke                  1
# Simida                         4
# Simitar                        2
# Sinofos                        2
# Smart-B                        1
# Solvigo                        1
# Sonic                          1
# Spectrum                       1
# State                          1
# Stock                          1
# Stomp                          2
# Success                        6
# Sulfex Gold                    4
# Sunstar Gold                   2
# Surprize                       1
# Surprize                       7
# Tafaban                        1
# Tafaban                        1
# Terror                         1
# Thiovet Jet                    1
# Thiovit Jet                    4
# Titonic                        2
# Top Guard                      1
# Topik                          4
# Topsin-M                       7
# Tornado                        1
# Total                          1
# Treaty                         1
# Trimectin                      3
# Tristar                        1
# Truce Xtra                     2
# Trump                          3
# Twister Plus                   1
# Tyrent                         1
# Ulala                          4
# Umbra                          1
# Valor                          5
# Vandal                         1
# Vesta                          1
# Virtako                        3
# Voliam Flexi                   2
# Walter Super                   6
# Wel-Sulf                       2
# Wendi                          4
# Winsta                         9
# Xi Chu                         2
# Xiaowang                      44
# Xilaining                      1
# Yoloo Falonler                 1
# Yumei                          2
# Name: count, dtype: int64

# %%
df['Brand Name'].value_counts(ascending=False).sort_index(ascending=True)
# Out:
# Brand Name
# Acelam                         4
# Acord                          1
# Acrid                          1
# Acrobat MZ                     2
# Actara                         6
# Actara ST                      1
# Adventure                      1
# Agroguard                      1
# Aiker                          2
# Aimanli                        1
# Aliette                        7
# Ally Max                       1
# Alumphos                       1
# Angelic                        1
# Antracol                       3
# Assure                         1
# Atlantis                       3
# Atlantis Super                 1
# Axial XL                       7
# Azidox                         3
# Baohu                          4
# Baoke                          1
# Barrier                        1
# Belt                           1
# Bengard                        1
# Best Guard                     1
# Biaochu                        1
# Bolton                         3
# Broadway                       1
# Buctril Super                  3
# Burate                         1
# Cabrio Top                     4
# Caimeiqing                     1
# Calm                           1
# Cantus                         2
# Capnazole                      1
# Celest                         1
# Champion                       2
# Chemphy                        1
# Chisel                         3
# Chloronil                      1
# Clean Out                      2
# CleanWave                      2
# Clio                           5
# Cobox                          4
# Commando Plus                  1
# Confidor                      12
# Confidor                       1
# Connect                        3
# Conquest                       2
# Contaf Plus                    5
# Coragen                        2
# Core                           2
# Coredor                        3
# Curator                        1
# Cure                           6
# Curzate M8                     3
# Cyclon                         1
# Cyren                          3
# Danadim Progress               8
# Danitol                        1
# Decis Super                    2
# Defeater                       1
# Defeater                       1
# Defeater Plus                  1
# Deft                           3
# Degesch                        2
# Diesomil Platinium             2
# Dithane M-45                   3
# Dividend Star                  1
# Dolomite                       2
# Double                         1
# Voliam Flexi                   2
# Walter Super                   6
# Wel-Sulf                       2
# Wendi                          4
# Winsta                         9
# Xi Chu                         2
# Xiaowang                      44
# Xilaining                      1
# Yoloo Falonler                 1
# Yumei                          2
# Name: count, dtype: int64

# %%
import pandas as pd

df['Brand Name'] = (
    df['Brand Name']
    .astype(str)
    .str.strip()
    .str.lower()
    .str.replace(r'[-_/]', ' ', regex=True)
    .str.replace(r'\s+', ' ', regex=True)
    .str.title()
)

manual_map = {
    'Form 16': 'Form-16',
    'Ful Clear': 'Ful-Clear',
    'Ful Control': 'Ful-Control',
    'Ridomil Gold Mz': 'Ridomil Gold MZ',
    'Thiovet Jet': 'Thiovit Jet',
    'Kumulus Df': 'Kumulus-DF',
    'Kumulus D F': 'Kumulus-DF',
    'Liman Tian': 'Li Man Tian',
    'Hombre ': 'Hombre',
    'Defeater ': 'Defeater',
    'Sega Pest Clear': 'Sega',
    'Recado Xtra': 'Recado',
    'Hombre Excel': 'Hombre',
    'Double Star': 'Double',
    'Defeater Plus': 'Defeater',
    'Atlantis Super': 'Atlantis',
    'Actara St': 'Actara',
    'Segawin': 'Sega',
    'Romer': 'Romeo',
    'Core': 'Cure',
}
df['Brand Name'] = df['Brand Name'].replace(manual_map)
df['Brand Name'].value_counts(ascending=False).sort_index(ascending=True)
# Out:
# Brand Name
# Acelam                         4
# Acord                          1
# Acrid                          1
# Acrobat Mz                     2
# Actara                         7
# Adventure                      1
# Agroguard                      1
# Aiker                          2
# Aimanli                        1
# Aliette                        7
# Ally Max                       1
# Alumphos                       1
# Angelic                        1
# Antracol                       3
# Assure                         1
# Atlantis                       4
# Axial Xl                       7
# Azidox                         3
# Baohu                          4
# Baoke                          1
# Barrier                        1
# Belt                           1
# Bengard                        1
# Best Guard                     1
# Biaochu                        1
# Bolton                         3
# Broadway                       1
# Buctril Super                  3
# Burate                         1
# Cabrio Top                     4
# Caimeiqing                     1
# Calm                           1
# Cantus                         2
# Capnazole                      1
# Celest                         1
# Champion                       2
# Chemphy                        1
# Chisel                         3
# Chloronil                      1
# Clean Out                      2
# Cleanwave                      2
# Clio                           5
# Cobox                          4
# Commando Plus                  1
# Confidor                      13
# Connect                        3
# Conquest                       2
# Contaf Plus                    5
# Coragen                        2
# Coredor                        3
# Curator                        1
# Cure                           8
# Curzate M8                     3
# Cyclon                         1
# Cyren                          3
# Danadim Progress               8
# Danitol                        1
# Decis Super                    2
# Defeater                       3
# Deft                           3
# Degesch                        2
# Diesomil Platinium             2
# Dithane M 45                   3
# Dividend Star                  1
# Dolomite                       2
# Double                         2
# Dragon                         1
# Dynasty Cst                    1
# Editor                         2
# Emesto                         1
# Equal                          2
# Equip                          1
# Evito                          2
# Fenithrin                      1
# Ferterra                       1
# Finer                          5
# Folio Gold                     2
# Form-16                      927
# Forward                        2
# Ful-Clear                     10
# Ful-Control                    2
# Gabbar                         1
# Gengwei                       35
# Glycel                         3
# Guangyan                       1
# Halonil                        1
# Helb Star                      1
# Hokko Kasumin                  1
# Hombre                         7
# Impyr                          1
# Janitor                        3
# Ji Run                         1
# K Best                        11
# Kelion                         2
# Knocker                        4
# Knocket Out                    1
# Kocide 3000                    1
# Korner                         1
# Kuai Ben                       4
# Kumulus-DF                     5
# Lancer Gold                    3
# Lannate                        2
# Laser                          1
# Lesenta                        1
# Li Man Tian                    2
# Limin Lingxiu                  2
# Logran                         1
# Lorsban                        4
# Lv Yu Dou                      1
# Machete                        1
# Maidian                        1
# March                          1
# Mauzer                         1
# Mebrom                         5
# Meishile                       1
# Melody Duo                     2
# Mera                           3
# Mesotrione + Atrazine          1
# Metric                         1
# Miaoyou                        7
# Mission Extra                  4
# Moncut                         1
# Morewise                       1
# Mospilan                       2
# Movento                        3
# Nanok                          2
# Nativo                         3
# Naturalyte Fruit Fly Bait      1
# Netzschwefel Stulln            6
# Oberon Speed                   3
# Orcus                          2
# Oshin                          1
# Output                         1
# Oxyrich                        2
# Oxyzone                        1
# Pallas                         1
# Panida Grande                  1
# Pivot                          1
# Plenum                         1
# Polyram Df                     7
# Primextra Gold                 2
# Proaxis                        1
# Proclaim                       3
# Profile                        1
# Protocol                       1
# Pucheng Star                   6
# Puffer                        10
# Puma Super                     1
# Pyramid Plus                   2
# Radiant                        5
# Rally                          2
# Recado                        10
# Regent                         4
# Rescue                         1
# Revus                          1
# Ridomil Gold MZ                3
# Rifit                          2
# Romeo                          4
# Roundup Power Max              2
# Rovral                         1
# Runner                         1
# Saaf                           2
# Saprofon                       2
# Scotts                         1
# Sega                          12
# Sencor                         1
# Sevin                          1
# Shincar                        2
# Shogun                         1
# Shuang Cao Ke                  1
# Simida                         4
# Simitar                        2
# Sinofos                        2
# Smart B                        1
# Solvigo                        1
# Sonic                          1
# Spectrum                       1
# State                          1
# Stock                          1
# Stomp                          2
# Success                        6
# Sulfex Gold                    4
# Sunstar Gold                   2
# Surprize                       8
# Tafaban                        2
# Terror                         1
# Thiovit Jet                    5
# Titonic                        2
# Top Guard                      1
# Topik                          4
# Topsin M                       7
# Tornado                        1
# Total                          1
# Treaty                         1
# Trimectin                      3
# Tristar                        1
# Truce Xtra                     2
# Trump                          3
# Twister Plus                   1
# Tyrent                         1
# Ulala                          4
# Umbra                          1
# Valor                          5
# Vandal                         1
# Vesta                          1
# Virtako                        3
# Voliam Flexi                   2
# Walter Super                   6
# Wel Sulf                       2
# Wendi                          4
# Winsta                         9
# Xi Chu                         2
# Xiaowang                      44
# Xilaining                      1
# Yoloo Falonler                 1
# Yumei                          2
# Name: count, dtype: int64

# %%
df['Origin'].value_counts()
# Out:
# Origin
# China          1039
# India           297
# Germany          59
# USA              33
# France           16
# Indonesia        16
# Denmark          15
# Australia        13
# Japan            12
# Malaysia          8
# Egypt             7
# Italy             4
# Singapore         4
# Switzerland       3
# Vietnam           3
# Austria           3
# Taiwan            2
# Korea             2
# UK                2
# Austalia          1
# Ausrtia           1
# South Korea       1
# Spain             1
# Bulgaria          1
# England           1
# Malysia           1
# Name: count, dtype: int64

# %%
origin_dict = {
    'Malysia': 'Malaysia',
    'England': 'UK',
    'Korea': 'South Korea',
    'Ausrtia': 'Austria',
    'Austalia': 'Australia',
}

df['Origin'].replace(origin_dict, inplace=True)
df['Origin'].value_counts()
# Out:
# /tmp/ipython-input-3762645648.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Origin'].replace(origin_dict, inplace=True)
# Origin
# China          1039
# India           297
# Germany          59
# USA              33
# France           16
# Indonesia        16
# Denmark          15
# Australia        14
# Japan            12
# Malaysia          9
# Egypt             7
# Italy             4
# Austria           4
# Singapore         4
# Switzerland       3
# UK                3
# South Korea       3
# Vietnam           3
# Taiwan            2
# Spain             1
# Bulgaria          1
# Name: count, dtype: int64

# %%
df['PSI'].value_counts()
# Out:
# PSI
# CU                852
# NMCI              458
# BALTIC             83
# Baltic             82
# ICI                53
# Cotecna            11
# Japan               2
# C.N                 1
# BALTIC Control      1
# PIC                 1
# China               1
# Name: count, dtype: int64

# %%
df.head(50)
# Out:
#           Date                 Job No.                    Firm Name  \
# 0   2017-01-02            C/PK/QC16015                EXIN CHEMICAL
# 1   2017-01-02        C/S/PK/170059/16                NEW AGRI CARE
# 2   2017-01-02              CU16119148                TARA IMPERIAL
# 3   2017-01-02              CU16119110                TARA IMPERIAL
# 4   2017-01-03            PK-130617/16           SUN CROP PESTICIDE
# 5   2017-01-03              CU16119088            SINO PAK CHEMICAL
# 6   2017-01-03            BTIN/1247/16         FOURBROTHER BIOLOGIC
# 7   2017-01-04              CU16119140         SAYBAN INTERNATIONAL
# 8   2017-01-04              CU16129171                          ICI
# 9   2017-01-04              CU16119029           PAK CHINA CHEMICAL
# 10  2017-01-04             8604/16  RE                        BAYER
# 11  2017-01-04            8580/16   LW                     SYNGENTA
# 12  2017-01-05            BCCHP0001944                       WARBLE
# 13  2017-01-06            C/PK/QC16021              PLUS ENTERPRISE
# 14  2017-01-06              CU16119091                AQ ENTERPRISE
# 15  2017-01-06              CU16129199                  ARYSTA LIFE
# 16  2017-01-06              CU16119098                AQ ENTERPRISE
# 17  2017-01-06              CU16129173                    AYAN CROP
# 18  2017-01-06              CU16119149                TARA IMPERIAL
# 19  2017-01-06              CU16129215                AQ ENTERPRISE
# 20  2017-01-06  NMCI/MUM/16/17/2005601              AGGRIO CHEMICAL
# 21  2017-01-06             CU161190085                  JAFFER AGRO
# 22  2017-01-09            C/PK/QC16020              PLUS ENTERPRISE
# 23  2017-01-09              FW16102496            NATIONAL CHEMICAL
# 24  2017-01-09              8579/16 LW                     SYNGENTA
# 25  2017-01-09             8583/16  RE                        BAYER
# 26  2017-01-09              CU16119134  PRIME BIOLOGICAL ENTERPRISE
# 27  2017-01-10              CU16119059                    CHEM CHEM
# 28  2017-01-10           C/PK/QC/16018                EXIN CHEMICAL
# 29  2017-01-11              CU16129220                AQ ENTERPRISE
# 30  2017-01-11              CU16088641                          ICI
# 31  2017-01-12              CU16129174              AURIGA CHEMICAL
# 32  2017-01-12            C/PK/QC16017                    AYAN CROP
# 33  2017-01-12              CU16129147                TARA IMPERIAL
# 2       CU    Herbicide         NaN        41.0            SOLUBLE LIQUID
# 3       CU    Fungicide         NaN        72.0         WAIGHTABLE POWDER
# 4     NMCI    Herbicide         NaN        88.8      WEIGHTABLE GRANULERS
# 5       CU  Insecticide         NaN        80.0      WATER SOLUBLE POWDER
# 6   BALTIC    Herbicide         NaN        15.0         WAIGHTABLE POWDER
# 7       CU  Insecticide         NaN        80.0      WATER SOLUBLE POWDER
# 8       CU  Insecticide         NaN        80.0      WATER SOLUBLE POWDER
# 9       CU     Fumigant         NaN        56.0               ALP TABLETS
# 10     ICI  Insecticide         NaN       372.5       FLOWABLE SUSPENSION
# 11     ICI    Fungicide         NaN        68.0      WEIGHTABLE GRANULERS
# 12  BALTIC    Fungicide         NaN        70.0         WAIGHTABLE POWDER
# 13    NMCI    Herbicide         NaN        55.0       SOLUBLE CONCENTRATE
# 14      CU    Fungicide         NaN        40.0       SOLUBLE CONCENTRATE
# 15      CU    Fungicide         NaN        72.0         WAIGHTABLE POWDER
# 16      CU    Fungicide         NaN        25.0  EMULSIFIABLE CONCENTRATE
# 17      CU    Fungicide         NaN        70.0         WAIGHTABLE POWDER
# 18      CU    Herbicide         NaN        41.0            SOLUBLE LIQUID
# 19      CU  Insecticide         NaN        25.0         WAIGHTABLE POWDER
# 20    NMCI    Fungicide         NaN        80.0      WEIGHTABLE GRANULERS
# 21      CU  Insecticide         NaN        40.0  EMULSIFIABLE CONCENTRATE
# 22    NMCI    Herbicide         NaN        55.0       SOLUBLE CONCENTRATE
# 23  BALTIC     Fumigant         NaN        98.0           2% CHLOROPICRIN
# 24     ICI    Fungicide         NaN        80.0      WEIGHTABLE GRANULERS
# 25      CU    Fungicide         NaN        70.0         WAIGHTABLE POWDER
# 26      CU  Insecticide         NaN        25.0         WAIGHTABLE POWDER
# 27      CU  Insecticide         NaN        25.0         WAIGHTABLE POWDER
# 28    NMCI    Fungicide         NaN        72.0         WAIGHTABLE POWDER
# 29      CU    Herbicide         NaN        48.0       SOLUBLE CONCENTRATE
# 30      CU    Fungicide         NaN        32.5       SOLUBLE CONCENTRATE
# 31      CU    Fungicide         NaN        60.0      WEIGHTABLE GRANULERS
# 32    NMCI    Herbicide         NaN        55.0       SOLUBLE CONCENTRATE
# 33      CU  Insecticide         NaN        25.0         WAIGHTABLE POWDER
# 34      CU  Insecticide         NaN        18.0       CONTROL FORMULATION
# 35      CU  Insecticide         NaN        25.0      WEIGHTABLE GRANULERS
# 36    NMCI    Fungicide         NaN        72.0         WAIGHTABLE POWDER
# 37      CU    Herbicide         NaN        20.0            SOLUBLE LIQUID
# 38      CU    Fungicide         NaN        10.0  EMULSIFIABLE CONCENTRATE
# 39      CU    Herbicide         NaN       480.0           GRAMS PER LITRE
# 40      CU    Herbicide         NaN        55.0       SOLUBLE CONCENTRATE
# 41      CU    Herbicide         NaN        50.0         WAIGHTABLE POWDER
# 42      CU    Fungicide         NaN        72.0         WAIGHTABLE POWDER
# 43      CU    Herbicide         NaN        48.0       SOLUBLE CONCENTRATE
# 44      CU    Fungicide         NaN        25.0  EMULSIFIABLE CONCENTRATE
# 45      CU    Fungicide         NaN        80.0      WEIGHTABLE GRANULERS
# 46   Japan    Fungicide         NaN        70.0         WAIGHTABLE POWDER
# 47  BALTIC    Fungicide         NaN        50.0         WAIGHTABLE POWDER
# 48      CU    Herbicide         NaN        38.0       SOLUBLE CONCENTRATE
# 49      CU    Herbicide         NaN        55.0       SOLUBLE CONCENTRATE

# %%
psi_dict = {
    'BALTIC Control': 'BALTIC',
    'Baltic': 'BALTIC',
}

df['PSI'].replace(psi_dict, inplace=True)
df['PSI'].value_counts()
# Out:
# /tmp/ipython-input-460777582.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PSI'].replace(psi_dict, inplace=True)
# PSI
# CU         852
# NMCI       458
# BALTIC     166
# ICI         53
# Cotecna     11
# Japan        2
# C.N          1
# PIC          1
# China        1
# Name: count, dtype: int64

# %%
# ==========
# Histogram
# ==========
plt.figure(figsize=(8,5))
sns.histplot(df['Quantity (lit/kg)'], kde=True, color='skyblue', bins=20)
plt.title("Histogram of Quantity (lit/kg)")
plt.xlabel("Quantity (lit/kg)")
plt.ylabel("Frequency")

plt.figtext(0.5, -0.05, "Histogram shows how imported quantities are distributed.", ha="center", fontsize=10)
plt.show()

# # =========================
# # Boxplot
# # =========================
# plt.figure(figsize=(8,3))
# sns.boxplot(x=df['Quantity (lit/kg)'], color='lightgreen')
# plt.title("Boxplot of Quantity (lit/kg)")
# plt.xlabel("Quantity (lit/kg)")

# plt.figtext(0.5, -0.05, "Boxplot highlights the spread and identifies large quantity outliers.", ha="center", fontsize=10)
# plt.show()

# %%
# =========================
# Histogram with legend
# =========================
plt.figure(figsize=(8,5))
sns.histplot(df['C & FValue'], kde=True, color='lightcoral', bins=20)
plt.title("Histogram of C & F Value")
plt.xlabel("C & F Value")
plt.ylabel("Frequency")

# Good legend/insight
plt.figtext(0.5, -0.05, "Histogram shows how C & F values are distributed across imports.", ha="center", fontsize=10)
plt.show()

# =========================
# Boxplot with legend
# =========================
plt.figure(figsize=(8,3))
sns.boxplot(x=df['C & FValue'], color='lightyellow')
plt.title("Boxplot of C & F Value")
plt.xlabel("C & F Value")

# Good legend/insight
plt.figtext(0.5, -0.05, "Boxplot highlights the spread and identifies high-value outliers.", ha="center", fontsize=10)
plt.show()

# %%
# Summary statistics
print(df['Total Value (Rs.)'].describe())

# Missing values
print("Missing values:", df['Total Value (Rs.)'].isnull().sum())

# =========================
# Histogram
# =========================
plt.figure(figsize=(8,5))
sns.histplot(df['Total Value (Rs.)'], kde=True, color='lightblue', bins=20)
plt.title("Histogram of Total Value (Rs.)")
plt.xlabel("Total Value (Rs.)")
plt.ylabel("Frequency")

plt.figtext(0.5, -0.05, "It shows how total value of imports varies.", ha="center", fontsize=10)
plt.show()

# =========================
# Boxplot
# =========================
plt.figure(figsize=(8,3))
sns.boxplot(x=df['Total Value (Rs.)'], color='lightgreen')
plt.title("Boxplot of Total Value (Rs.)")
plt.xlabel("Total Value (Rs.)")

# Simple legend/insight
plt.figtext(0.5, -0.05, "It shows distribution and outliers in total value.", ha="center", fontsize=10)
plt.show()
# Out:
# count    1.545000e+03
# mean     9.417707e+06
# std      1.773937e+07
# min      1.643000e+05
# 25%      3.222400e+06
# 50%      5.549100e+06
# 75%      9.361920e+06
# max      2.745930e+08
# Name: Total Value (Rs.), dtype: float64
# Missing values: 0

# %%
plt.figure(figsize=(8,5))
df['Category'] = encoders['Category'].inverse_transform(df['Category'])
sns.countplot(x='Category', data=df)
plt.title("Count Plot: Category")
plt.figtext(0.5, -0.05, "insecticide was the most imported pesticide in 2017.", ha="center", fontsize=10)

plt.show()

# %%
df['Category'].unique()
# Out:
# array(['Herbicide', 'Fungicide', 'Insecticide', 'Fumigant', 'Biological',
#        'Acaricide'], dtype=object)

# %%
df['Origin'].unique()
# Out:
# array(['China', 'India', 'Australia', 'France', 'USA', 'Germany',
#        'Austria', 'Japan', 'Switzerland', 'Taiwan', 'Denmark',
#        'Indonesia', 'Italy', 'Malaysia', 'Singapore', 'South Korea',
#        'Egypt', 'UK', 'Vietnam', 'Spain', 'Bulgaria'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Quantity (lit/kg)', y='Total Value (Rs.)', data=df)
plt.title("Scatter Plot: Quantity vs Total Value")
plt.xlabel("Quantity (lit/kg)")
plt.ylabel("Total Value (Rs.)")

# Short legend/insight
plt.figtext(0.5, -0.05, "It shows how total value changes with quantity.", ha="center", fontsize=10)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Category', y='Quantity (lit/kg)', data=df)

plt.title("Boxplot: Category vs Quantity (lit/kg)")

# Short legend/insight
plt.figtext(0.5, -0.05, "It shows how quantity varies across different categories.", ha="center", fontsize=10)

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='C & FValue', y='Total Value (Rs.)', data=df)

plt.title("Scatter Plot: C & F Value vs Total Value")
plt.xlabel("C & F Value")
plt.ylabel("Total Value (Rs.)")

# Short legend/insight
plt.figtext(0.5, -0.05, "It shows the relationship between C & F Value and Total Value.", ha="center", fontsize=10)

plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

cols_to_encode = ['Firm Name', 'Brand Name', 'Type', 'Origin', 'PSI', 'Category']
encoders = {}

for col in cols_to_encode:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

# Inverse transform later if needed
# df['Brand Name'] = encoders['Brand Name'].inverse_transform(df['Brand Name'])

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Total Value (Rs.)'], kde=True, color='lightgreen', bins=20)
plt.title("Histogram of Total Value (Rs.)")
plt.xlabel("Total Value (Rs.)")
plt.ylabel("Frequency")

# Short legend/insight in one line
plt.figtext(0.5, -0.05, "It shows how total value varies.", ha="center", fontsize=10)

plt.show()

# %%
# Clean the country names
df['Origin_Name'] = (
    df['Origin']
    .astype(str)
    .str.strip()
    .str.title()     # Converts 'china', 'CHINA', ' China ' → 'China'
)

# Count countries
origin_counts = df['Origin_Name'].value_counts()

# Safety check
if origin_counts.empty:
    print("⚠️ No countries found in Origin column — check data.")
else:
    # Calculate percentages
    percentages = 100 * origin_counts / origin_counts.sum()
    labels_with_pct = [
        f'{country} ({pct:.1f}%)'
        for country, pct in zip(origin_counts.index, percentages)
    ]

    # Top country
    top_country = origin_counts.idxmax()

    # Plot
    plt.figure(figsize=(8,6))
    plt.pie(origin_counts, startangle=90)

    plt.legend(
        labels_with_pct,
        title="Countries",
        loc="center left",
        bbox_to_anchor=(1, 0.5)
    )
    plt.title("Distribution of Countries (Origin)")
    plt.axis('equal')

    # Insight text
    plt.text(
        0.5, -0.1,
        f"This chart shows that {top_country} is the top provider of pesticides.",
        ha='center',
        va='center',
        fontsize=11,
        transform=plt.gca().transAxes
    )

    plt.show()

# %%
category_map = {
    1: 'Herbicide',
    2: 'Fungicide',
    3: 'Insecticide',
    4: 'Fumigant',
    5: 'Biological',
    6: 'Acaricide'
}

df['Category_Name'] = df['Category'].map(category_map)
category_counts = df['Category_Name'].value_counts()

# Calculate percentages
percentages = 100 * category_counts / category_counts.sum()
labels_with_pct = [f'{cat} ({pct:.1f}%)' for cat, pct in zip(category_counts.index, percentages)]

# Find the highest imported category
top_category = category_counts.idxmax()

plt.figure(figsize=(8,6))
plt.pie(category_counts, startangle=90)
plt.legend(labels_with_pct, title="Category", loc="center left", bbox_to_anchor=(1, 0.5))
plt.title("Distribution of Categories")
plt.axis('equal')

# ⭐ Simple final insight sentence
plt.text(
    0.5, -0.1,
    f"This chart shows that {top_category} is the most imported category.",
    ha='center',
    va='center',
    fontsize=11,
    transform=plt.gca().transAxes
)

plt.show()

# %%
df.columns = df.columns.str.strip().str.replace('\n', '')

# List of numeric columns
numeric_cols = ['Quantity (lit/kg)', 'Total Value (Rs.)']

# -------------------------
# 1. Histograms with Legends
# -------------------------
for col in numeric_cols:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col], kde=True, bins=20, color='skyblue')

    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')


    plt.text(
        0.98, 0.95,
        "Insight: Distribution pattern shows\nkey concentration of values.",
        transform=plt.gca().transAxes,
        ha='right',
        va='top',
        fontsize=9,
        bbox=dict(facecolor='white', alpha=0.6)
    )

    plt.show()

# %%
df.head(20)
# Out:
#           Date           Job No.  Firm Name  Brand Name  \
# 0   2017-01-02      C/PK/QC16015         39         212
# 1   2017-01-02  C/S/PK/170059/16         67          59
# 2   2017-01-02        CU16119148         99          77
# 3   2017-01-02        CU16119110         99          77
# 4   2017-01-03      PK-130617/16         95         196
# 5   2017-01-03        CU16119088         89          77
# 6   2017-01-03      BTIN/1247/16         42          77
# 7   2017-01-04        CU16119140         87          77
# 8   2017-01-04        CU16129171         54          77
# 9   2017-01-04        CU16119029         70          77
# 10  2017-01-04       8604/16  RE         25          88
# 11  2017-01-04      8580/16   LW         97         155
# 12  2017-01-05      BCCHP0001944        107          77
# 13  2017-01-06      C/PK/QC16021         79         212
# 14  2017-01-06        CU16119091         20          70
# 15  2017-01-06        CU16129199         21         180
# 16  2017-01-06        CU16119098         20          77
# 17  2017-01-06        CU16129173         23          77
# 18  2017-01-06        CU16119149         99          77
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               783 non-null    object
#  1   Job No.            1545 non-null   object
#  2   Firm Name          1545 non-null   int64
#  3   Brand Name         1545 non-null   int64
#  4   Comman Name        1545 non-null   object
#  5   Quantity (lit/kg)  1545 non-null   float64
#  6   C & FValue         1545 non-null   float64
#  7   Total Value (Rs.)  1545 non-null   float64
#  8   Origin             1545 non-null   object
#  9   Reg. No.           1545 non-null   object
#  10  PSI                1545 non-null   int64
#  11  Category           1545 non-null   int64
#  12  Origin_Name        1545 non-null   object
#  13  Percentage         1545 non-null   float64
#  14  Type               1545 non-null   int64
#  15  Category_Name      1542 non-null   object
# dtypes: float64(4), int64(5), object(7)
# memory usage: 237.5+ KB

# %%
plt.figure(figsize=(10, 8))
# Count and sort
origin_counts = df['Origin_Name'].value_counts().sort_values(ascending=False)

sns.barplot(x=origin_counts.values, y=origin_counts.index, palette='viridis')
plt.title('Imports by Country of Origin')
plt.xlabel('Number of Imports')
plt.ylabel('Country')
plt.show()
# Out:
# /tmp/ipython-input-1227474350.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=origin_counts.values, y=origin_counts.index, palette='viridis')

# %%
plt.figure(figsize=(8,5))
# Apply log scale to x-axis to normalize the view
sns.histplot(df['Total Value (Rs.)'], kde=True, log_scale=True, color='lightblue')
plt.title("Log-Histogram of Total Value (Rs.)")
plt.xlabel("Total Value (Log Scale)")
plt.show()

# %%
import matplotlib.dates as mdates

# Ensure Date format is correct
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')

# Aggregate data by Month
# We use 'M' for month-end frequency
monthly_imports = df.set_index('Date').resample('M')['Total Value (Rs.)'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_imports, x='Date', y='Total Value (Rs.)', marker='o', color='navy')

# Formatting the x-axis to make dates readable
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=3))
plt.xticks(rotation=45)
plt.title('Time Series: Total Import Value Over Time')
plt.ylabel('Total Value (Rs.)')
plt.grid(True, linestyle='--', alpha=0.5)

# --- INSIGHT TEMPLATE ---
insight_text = (
    "INSIGHTS:\n"
    "1. Peak month(s): [May].\n"
    "2. Overall trend: [Volatile].\n"
    "3. Gaps: [least imports in June, August]"
)

plt.figtext(0.15, -0.15, insight_text, ha='left', fontsize=11,
            bbox=dict(facecolor='#f0f0f0', alpha=1, pad=10))

plt.show()
# Out:
# /tmp/ipython-input-1288390402.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_imports = df.set_index('Date').resample('M')['Total Value (Rs.)'].sum().reset_index()

# %%
import matplotlib.ticker as ticker
#df['Firm Name'] = df['Firm Name'].astype(str)
#df['Brand Name'] = encoders['Brand Name'].inverse_transform(df['Brand Name'].astype(int))
# Function to format large numbers (e.g., 1,000,000 -> 1M)
def human_format(num, pos):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    return '%.1f%s' % (num, ['', 'K', 'M', 'B'][magnitude])

# Set up the canvas
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

# -------------------------------------------------------
# Chart 1: Top 10 Firms by Value (Horizontal)
# -------------------------------------------------------
# Sort ascending so the largest bar is at the top when plotting horizontally
top_firms = df.groupby('Firm Name')['Total Value (Rs.)'].sum().nlargest(10).sort_values(ascending=True)

sns.barplot(x=top_firms.values, y=top_firms.index, ax=axes[0], palette='viridis', orient='h')

axes[0].set_title('Top 10 Firms by Total Import Value', fontsize=14)
axes[0].set_xlabel('Total Value (Rs.)', fontsize=12)
axes[0].set_ylabel('Firm Name', fontsize=12)
# Apply the readable number formatter to the X-axis
axes[0].xaxis.set_major_formatter(ticker.FuncFormatter(human_format))
axes[0].grid(axis='x', linestyle='--', alpha=0.5)


# -------------------------------------------------------
# Chart 2: Top 10 Brands by Quantity (Horizontal)
# -------------------------------------------------------

top_brands = df.groupby('Brand Name')['Quantity (lit/kg)'].sum().nlargest(10).sort_values(ascending=True)

sns.barplot(x=top_brands.values, y=top_brands.index, ax=axes[1], palette='magma', orient='h')

axes[1].set_title('Top 10 Brands by Quantity Imported', fontsize=14)
axes[1].set_xlabel('Quantity (lit/kg)', fontsize=12)
axes[1].set_ylabel('Brand Name', fontsize=12)
# Apply the readable number formatter to the X-axis
axes[1].xaxis.set_major_formatter(ticker.FuncFormatter(human_format))
axes[1].grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-220729605.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_firms.values, y=top_firms.index, ax=axes[0], palette='viridis', orient='h')
# /tmp/ipython-input-220729605.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_brands.values, y=top_brands.index, ax=axes[1], palette='magma', orient='h')

# %%
# Select only numeric columns for correlation
numeric_df = df[['Quantity (lit/kg)', 'C & FValue', 'Total Value (Rs.)', 'Percentage']]

plt.figure(figsize=(8, 6))
# Calculate correlation matrix
corr_matrix = numeric_df.corr()

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Key Numerical Features')

# --- INSIGHT TEMPLATE ---
plt.figtext(0.5, -0.1,
            "INSIGHTS:\n"
            "1. Quantity vs Total Value:[Positive correlation.]\n"
            "2. C & F Value vs Quantity:[-ve correlation suggests bulk is cheaper].\n"
            "3. Percentage vs Price:[higher concentration is  more expensive]",
            ha='center', fontsize=11, bbox=dict(facecolor='#f0f0f0', alpha=1, pad=10))

plt.show()

# %%
# Create a mapping dictionary for Category IDs (if encoded)
# If your Category column is already text, this map won't break anything.

# Create a readable Category Name column
# We check if it's numeric first to avoid errors if it's already text
if pd.api.types.is_numeric_dtype(df['Category']):
    df['Category_Name'] = df['Category'].map(category_map)
else:
    df['Category_Name'] = df['Category']

plt.figure(figsize=(12, 6))

# We use C & F Value as the Unit Price
# A Log Scale is applied because prices often range from very low ($1) to very high ($100+)
sns.boxplot(x='Category_Name', y='C & FValue', data=df, palette='Set2')
plt.yscale('log')

plt.title('Unit Price Distribution (C & F Value in USD) by Category')
plt.ylabel('Unit Price (USD) - Log Scale')
plt.xlabel('Pesticide Category')
plt.grid(True, which="both", ls="--", alpha=0.2)

# --- INSIGHT TEMPLATE ---
insight_text = (
    "INSIGHTS:\n"
    "1. Premium Products: insecticide has the highest median unit price.\n"
    "2. Cost Variance: insecticide shows the widest price spread.\n"
    "3. Cheapest Option: [Category Name] generally has the lowest cost per unit."
)

plt.figtext(0.5, -0.15, insight_text, ha='center', fontsize=11,
            bbox=dict(facecolor='#f0f0f0', alpha=1, pad=10))

plt.show()
# Out:
# /tmp/ipython-input-1317903154.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category_Name', y='C & FValue', data=df, palette='Set2')
